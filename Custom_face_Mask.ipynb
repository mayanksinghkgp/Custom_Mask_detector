# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Training the model with custom labeled images

# %%
# !unzip '/content/drive/MyDrive/Colab_files/yolo_mask.zip' -d '/content/mask_data/'
# Out:
# Archive:  /content/drive/MyDrive/Colab_files/yolo_mask.zip
#   inflating: /content/mask_data/images/classes.names
#   inflating: /content/mask_data/images/classes.txt
#   inflating: /content/mask_data/images/test.txt
#    creating: /content/mask_data/images/test/
#   inflating: /content/mask_data/images/test/nouveau-virus-en-chine-la-ville-de-wuhan-mise-en-quarantaine-1.jpg
#   inflating: /content/mask_data/images/test/nouveau-virus-en-chine-la-ville-de-wuhan-mise-en-quarantaine-1.txt
#   inflating: /content/mask_data/images/test/nq50003q8p6q8n72p7o.jpg
#   inflating: /content/mask_data/images/test/nq50003q8p6q8n72p7o.txt
#   inflating: /content/mask_data/images/test/nq50003q8p707o0p586.jpg
#   inflating: /content/mask_data/images/test/nq50003q8p707o0p586.txt
#   inflating: /content/mask_data/images/test/nqn000p326n081sq0np.jpg
#   inflating: /content/mask_data/images/test/nqn000p326n081sq0np.txt
#   inflating: /content/mask_data/images/test/nqn000p326o7525q707.jpg
# ...

# %%
# !git clone 'https://github.com/AlexeyAB/darknet/' 'a/'
# Out:
# Cloning into 'a'...
# remote: Enumerating objects: 15368, done.
# remote: Total 15368 (delta 0), reused 0 (delta 0), pack-reused 15368
# Receiving objects: 100% (15368/15368), 13.98 MiB | 17.63 MiB/s, done.
# Resolving deltas: 100% (10335/10335), done.

# %%
# !apt install libopencv-dev python-opencv ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# libopencv-dev is already the newest version (3.2.0+dfsg-4ubuntu0.1).
# The following NEW packages will be installed:
#   python-opencv
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 535 kB of archives.
# After this operation, 2,944 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python-opencv amd64 3.2.0+dfsg-4ubuntu0.1 [535 kB]
# Fetched 535 kB in 1s (658 kB/s)
# Selecting previously unselected package python-opencv.
# (Reading database ... 155222 files and directories currently installed.)
# Preparing to unpack .../python-opencv_3.2.0+dfsg-4ubuntu0.1_amd64.deb ...
# Unpacking python-opencv (3.2.0+dfsg-4ubuntu0.1) ...
# Setting up python-opencv (3.2.0+dfsg-4ubuntu0.1) ...

# %%
# !sed -i 's/OPENCV=0/OPENCV=1/g' a/Makefile
# !sed -i 's/GPU=0/GPU=1/g' a/Makefile
#!sed -i 's/CUDNN=0/CUDNN=1/g' Makefile
# %pycat Makefile

# %%
# %cd /content/a
# Out:
# /content/a

# %%
# !ls
# Out:
# 3rdparty		darknet_video.py       net_cam_v4.sh
# build			data		       README.md
# build.ps1		image_yolov3.sh        results
# cfg			image_yolov4.sh        scripts
# cmake			include		       src
# CMakeLists.txt		json_mjpeg_streams.sh  vcpkg.json
# DarknetConfig.cmake.in	LICENSE		       video_yolov3.sh
# darknet_images.py	Makefile	       video_yolov4.sh
# darknet.py		net_cam_v3.sh

# %%
# !make

# %%
# %cd ~
# Out:
# /root

# %%
# %cd /content/
# Out:
# /content

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 1s (451 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package dos2unix.
# ...

# %%
# !dos2unix /content/train.txt
# !dos2unix /content/test.txt
# !dos2unix /content/valid.txt
# !dos2unix /content/obj.data
# !dos2unix /content/a/backup/yolov3_custommask_last.weights
# Out:
# dos2unix: /content/a/backup/yolov3_custommask_last.weights: No such file or directory
# dos2unix: Skipping /content/a/backup/yolov3_custommask_last.weights, not a regular file.

# %%
# !a/darknet detector train /content/obj.data /content/yolov3-tiny-prn.cfg /content/mask-yolov3-tiny-prn.weights -dont_show -clear
# Out:
#  CUDA-version: 11010 (11020), GPU count: 1
#  OpenCV version: 3.2.0
# yolov3-tiny-prn
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 4, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
# conv     16       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  16 0.150 BF
#    1 max                2x 2/ 2    416 x 416 x  16 ->  208 x 208 x  16 0.003 BF
#    2 conv     32       3 x 3/ 1    208 x 208 x  16 ->  208 x 208 x  32 0.399 BF
#    3 max                2x 2/ 2    208 x 208 x  32 ->  104 x 104 x  32 0.001 BF
#    4 conv     64       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  64 0.399 BF
#    5 max                2x 2/ 2    104 x 104 x  64 ->   52 x  52 x  64 0.001 BF
#    6 conv    128       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x 128 0.399 BF
#    7 max                2x 2/ 2     52 x  52 x 128 ->   26 x  26 x 128 0.000 BF
# ...

# %% [markdown]
# ### Testing the trained weights

# %%
# !unzip '/content/drive/MyDrive/Colab_files/Mask_config.zip'
# Out:
# Archive:  /content/drive/MyDrive/Colab_files/Mask_config.zip
#   inflating: mask-yolov3-tiny-prn.weights
#   inflating: obj.data
#  extracting: obj.names
#   inflating: test.txt
#   inflating: train.txt
#   inflating: valid.txt
#   inflating: yolov3-tiny-prn.cfg

# %%
# !dos2unix /content/train.txt
# !dos2unix /content/test.txt
# !dos2unix /content/valid.txt
# !dos2unix /content/obj.data
# !dos2unix /content/obj.names
# !dos2unix /content/yolov3-tiny-prn.cfg
# Out:
# dos2unix: converting file /content/train.txt to Unix format...
# dos2unix: converting file /content/test.txt to Unix format...
# dos2unix: converting file /content/valid.txt to Unix format...
# dos2unix: converting file /content/obj.data to Unix format...
# dos2unix: converting file /content/obj.names to Unix format...
# dos2unix: converting file /content/yolov3-tiny-prn.cfg to Unix format...

# %%
# !a/darknet detector test /content/obj.data /content/yolov3-tiny-prn.cfg /content/mask-yolov3-tiny-prn.weights check2.jpg
# Out:
#  CUDA-version: 11010 (11020), GPU count: 1
#  OpenCV version: 3.2.0
# Cannot load image data/labels/32_0.png
# Cannot load image data/labels/33_0.png
# Cannot load image data/labels/34_0.png
# Cannot load image data/labels/35_0.png
# Cannot load image data/labels/36_0.png
# Cannot load image data/labels/37_0.png
# Cannot load image data/labels/38_0.png
# Cannot load image data/labels/39_0.png
# Cannot load image data/labels/40_0.png
# Cannot load image data/labels/41_0.png
# Cannot load image data/labels/42_0.png
# Cannot load image data/labels/43_0.png
# Cannot load image data/labels/44_0.png
# Cannot load image data/labels/45_0.png
# Cannot load image data/labels/46_0.png
# Cannot load image data/labels/47_0.png
# Cannot load image data/labels/48_0.png
# Cannot load image data/labels/49_0.png
# Cannot load image data/labels/50_0.png
# Cannot load image data/labels/51_0.png
# Cannot load image data/labels/52_0.png
# Cannot load image data/labels/53_0.png
# ...
